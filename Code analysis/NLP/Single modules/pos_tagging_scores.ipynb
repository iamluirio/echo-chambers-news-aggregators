# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import csv

# %% [markdown]
# ## Total adjectives - 02/05/2023

# %%
tot_adj_U1_02 = [124, 32, 81, 101, 58, 48, 62, 43, 25, 162]
tot_adj_U2_02 = [110, 99, 47, 34, 41, 224, 65, 15, 150, 150]
tot_adj_U3_02 = [49, 41, 81, 110, 99, 47, 28, 81, 184, 70]
tot_adj_U4_02 = [55, 38, 59, 65, 110, 99, 47, 48, 48, 92]

# Dati per l'asse X e etichette
users = ['U1', 'U2', 'U3', 'U4']

plt.figure(figsize=(10, 6))

# Creazione del box plot
plt.boxplot([tot_adj_U1_02, tot_adj_U2_02, tot_adj_U3_02, tot_adj_U4_02], labels=users)

# Aggiunta di etichette e titoli
plt.xlabel('Users')
plt.ylabel('Total adjectives')

# Visualizzazione del box plot
plt.show()

# %% [markdown]
# ## Total number of words - 02/05/2023

# %%
tot_words_U1_02 = [733, 280, 789, 1074, 512, 383, 593, 439, 193, 1297]
tot_words_U2_02 = [896, 815, 485, 486, 2024, 1993, 653, 155, 1243, 1244]
tot_words_U3_02 = [441, 465, 555, 896, 815, 485, 260, 667, 1344, 686]
tot_words_U4_02 = [377, 263, 402, 473, 896, 815, 485, 313, 651, 839]

# Dati per l'asse X e etichette
users = ['U1', 'U2', 'U3', 'U4']

plt.figure(figsize=(10, 6))

# Creazione del box plot
plt.boxplot([tot_words_U1_02, tot_words_U2_02, tot_words_U3_02, tot_words_U4_02], labels=users)

# Aggiunta di etichette e titoli
plt.xlabel('Users')
plt.ylabel('Total words')

# Visualizzazione del box plot
plt.show()
