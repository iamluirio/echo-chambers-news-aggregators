# %% [markdown]
# # Day 02/05/2023

# %% [markdown]
# ## Average length scores

# %%
import matplotlib.pyplot as plt

# %%
avg_U1 = [5.31481481481482, 7.36363636363636, 4.16901408450704, 4.91346153846154, 5.53125, 8.1875, 5.97058823529412, 5.21875, 6.38461538461539, 5.65573770491803]
avg_U2 = [7.15555555555556, 5.58928571428571, 7.91304347826087, 5.37037037037037, 5.45762711864407, 5.33333333333333, 6.56666666666667, 5.78048780487805, 5.78048780487805, 0]
avg_U3 = [7.59090909090909, 6.26923076923077, 5.36363636363636, 7.15555555555556, 5.58928571428571, 7.91304347826087, 5.05263157894737, 4.97826086956522, 7.77966101694915, 4.1044776119403]
avg_U4 = [5.75, 6.4375, 4.44444444444444, 5.67567567567568, 7.15555555555556, 5.58928571428571, 7.91304347826087, 5.33333333333333, 6.1025641025641, 6.65909090909091]

# %%
data = [avg_U1, avg_U2, avg_U3, avg_U4]
labels = ['U1', 'U2', 'U3', 'U4']

# Specifica le dimensioni della figura
plt.figure(figsize=(10, 6))

plt.boxplot(data, labels=labels)
plt.xlabel('Users')
plt.ylabel('Scores')
plt.title('02/05/2023')

plt.show()

# %% [markdown]
# # Day 03/05/2023

# %% [markdown]
# ## Average Length score

# %%
avg_U1 = [6.53846153846154, 5.46875, 4.29032258064516, 5.81818181818182]
avg_U2 = [6.0625, 6.38333333333333, 5.55813953488372, 5.27777777777778]
avg_U3 = [7.97058823529412, 5.33333333333333, 4.85, 5.96078431372549]
avg_U4 = [7.22222222222222, 5.79166666666667, 5.52631578947368, 5.8125]

data = [avg_U1, avg_U2, avg_U3, avg_U4]
labels = ['U1', 'U2', 'U3', 'U4']

# Specifica le dimensioni della figura
plt.figure(figsize=(10, 6))

plt.boxplot(data, labels=labels)
plt.xlabel('Users')
plt.ylabel('Scores')
plt.title('03/05/2023')

plt.show()

# %% [markdown]
# # Day 04/05/2023

# %% [markdown]
# ## Average Length score

# %%
avg_U1 = [6.2015503875969, 6.33333333333333, 6.22222222222222, 5.14285714285714]
avg_U2 = [7.23529411764706, 5.89473684210526, 6.21621621621622, 5.45833333333333]
avg_U3 = [5.22058823529412, 5, 6.92307692307692, 6.90909090909091]
avg_U4 = [7, 6.43396226415094, 6, 5.96296296296296]

data = [avg_U1, avg_U2, avg_U3, avg_U4]
labels = ['U1', 'U2', 'U3', 'U4']

# Specifica le dimensioni della figura
plt.figure(figsize=(10, 6))

plt.boxplot(data, labels=labels)
plt.xlabel('Users')
plt.ylabel('Scores')
plt.title('04/05/2023')
# Out:
# Text(0.5, 1.0, '04/05/2023')
