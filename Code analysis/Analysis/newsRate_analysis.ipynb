# %% [markdown]
# # News Rate Analysis

# %% [markdown]
# ## Analysys carried out on different days (separately) on top 20 news for each day, for each user, and plotted a multi-bar graph for each topic.

# %% [markdown]
# ### Tuesday 21 March (Pier): Users 1 to 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
REP = [3, 1, 2, 2]
DEM = [6, 5, 8, 4]
UNB = [0, 0, 3, 7]
MIC = [2, 5, 1, 3]
OTH = [9, 9, 6, 4]
x = np.arange(len(REP))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 5)][::-1]  # Generate 5 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - 2.0 * bar_width, REP, bar_width, label='rep', color=colors[0])
ax.bar(x - 1.0 * bar_width, DEM, bar_width, label='dem', color=colors[1])
ax.bar(x, UNB, bar_width, label='unbiased', color=colors[2])
ax.bar(x + 1.0 * bar_width, MIC, bar_width, label='micro', color=colors[3])
ax.bar(x + 2.0 * bar_width, OTH, bar_width, label='others', color=colors[4])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U1', 'U2', 'U3', 'U4'], fontsize=16)  # Set x-axis label font size
ax.set_xlabel('Users', fontsize=20)

# Set y-axis label and font size
ax.set_ylabel('Num of News Articles', fontsize=20)

# Increase the y-axis tick labels font size
ax.tick_params(axis='y', labelsize=16)

# Add a legend and title
ax.legend(loc='upper right', fontsize=12)  # Adjust legend location to upper right

# Saving as eps plot image
plt.savefig('fig_5_a_new2.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Saturday 25 March (Pier): Users 1 to 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
REP = [1, 2, 4, 1]
DEM = [7, 1, 5, 5]
UNB = [0, 0, 0, 3]
MIC = [8, 16, 7, 3]
OTH = [4, 1, 4, 8]
x = np.arange(len(REP))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 5)]  # Generate 5 colors from the colormap starting at 0.2

ax.bar(x - 2.0 * bar_width, REP, bar_width, label='rep', color=colors[0])
ax.bar(x - 1.0 * bar_width, DEM, bar_width, label='dem', color=colors[1])
ax.bar(x, UNB, bar_width, label='unbiased', color=colors[2])
ax.bar(x + 1.0 * bar_width, MIC, bar_width, label='micro', color=colors[3])
ax.bar(x + 2.0 * bar_width, OTH, bar_width, label='others', color=colors[4])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U1', 'U2', 'U3', 'U4'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Num of News Articles', fontsize=14)

# Add a legend and title
ax.legend()

# Saving as eps plot image
plt.savefig('plots/saturday25_pier.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Wednesday 29 March (Pier): Users 5 to 8

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
MAC = [11, 12, 13, 8]
MIC = [5, 12, 7, 5]
OTH = [0, 0, 0, 7]
x = np.arange(len(MAC))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 3)]  # Generate 3 colors from the colormap starting at 0.2

ax.bar(x - bar_width, MAC, bar_width, label='macro', color=colors[0])
ax.bar(x, MIC, bar_width, label='micro', color=colors[1])
ax.bar(x + bar_width, OTH, bar_width, label='others', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U5', 'U6', 'U7', 'U8'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Num of News Articles', fontsize=14)

# Add a legend and title
ax.legend()

# Saving as eps plot image
plt.savefig('wednesday29_pier.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Wednesday 29 March (Ananya B.): Users 5 to 8

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
MAC = [16, 19, 17, 9]
MIC = [4, 1, 3, 11]
OTH = [0, 0, 0, 0]
x = np.arange(len(MAC))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 3)][::-1]  # Generate 3 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - bar_width, MAC, bar_width, label='macro', color=colors[0])
ax.bar(x, MIC, bar_width, label='micro', color=colors[1])
ax.bar(x + bar_width, OTH, bar_width, label='others', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I7', 'I8', 'I9', 'I10'], fontsize=16)
ax.set_xlabel('Users', fontsize=20)
ax.set_ylabel('Num of News Articles', fontsize=20)

# Set y-axis ticks
yticks = range(0, max(MAC + MIC + OTH) + 1, 2)  # set y-axis ticks to be integers
ax.set_yticks(yticks)

# Set y-axis tick labels
yticklabels = [str(y) if y % 2 == 0 else '' for y in yticks]  # set even numbers as tick labels
ax.set_yticklabels(yticklabels)

ax.tick_params(axis='y', labelsize=16)

# Add a legend and title
ax.legend(fontsize=14)

# Saving as eps plot image
plt.savefig('fig_6_a_new2.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Thursday 30 March (Pier): Users 5 to 8

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
MAC = [7, 2, 13, 5]
MIC = [3, 8, 2, 4]
OTH = [0, 0, 5, 11]
x = np.arange(len(MAC))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(1, 0.2, 3)]  # Invert the order of colors

ax.bar(x - bar_width, MAC, bar_width, label='macro', color=colors[0])
ax.bar(x, MIC, bar_width, label='micro', color=colors[1])
ax.bar(x + bar_width, OTH, bar_width, label='others', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U5', 'U6', 'U7', 'U8'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Num of News Articles', fontsize=14)

# Add a legend and title
ax.legend()

# Saving as eps plot image
plt.savefig('fig_3.1_a.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Thursday 30 March (Tarika): Users 7 to 10

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
MAC = [5, 11, 11, 8]
MIC = [8, 9, 9, 8]
OTH = [7, 0, 0, 4]
x = np.arange(len(MAC))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(1, 0.2, 3)]  # Invert the order of colors

ax.bar(x - bar_width, MAC, bar_width, label='macro', color=colors[0])
ax.bar(x, MIC, bar_width, label='micro', color=colors[1])
ax.bar(x + bar_width, OTH, bar_width, label='others', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U15', 'U16', 'U17', 'U18'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Num of News Articles', fontsize=14)

# Add a legend and title
ax.legend()

# Saving as eps plot image
plt.savefig('fig_3.1_b.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Fig. 6 b

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
MAC = [6, 11, 8, 11]
MIC = [10, 8, 12, 8]
OTH = [4, 1, 0, 1]
x = np.arange(len(MAC))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 3)][::-1]

ax.bar(x - bar_width, MAC, bar_width, label='macro', color=colors[0])
ax.bar(x, MIC, bar_width, label='micro', color=colors[1])
ax.bar(x + bar_width, OTH, bar_width, label='others', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I7', 'I8', 'I9', 'I10'], fontsize=16)
ax.set_xlabel('Users', fontsize=20)
ax.set_ylabel('Num of News Articles', fontsize=20)

ax.tick_params(axis='y', labelsize=16)

# Add a legend and title
ax.legend(fontsize=14)

# Saving as eps plot image
plt.savefig('fig_6_b_new2.eps', format='eps')


# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Fig. 5 b

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
REP = [0, 2, 1, 2, 3]
DEM = [6, 6, 6, 5, 1]
UNB = [1, 1, 3, 0, 2]
MIC = [4, 4, 2, 5, 6]
OTH = [2, 0, 2, 2, 0]
x = np.arange(len(REP)) + 8  # Shift the x-axis values to start from U9
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 5)][::-1]  # Generate 5 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - 2.0 * bar_width, REP, bar_width, label='rep', color=colors[0])
ax.bar(x - 1.0 * bar_width, DEM, bar_width, label='dem', color=colors[1])
ax.bar(x, UNB, bar_width, label='unbiased', color=colors[2])
ax.bar(x + 1.0 * bar_width, MIC, bar_width, label='micro', color=colors[3])
ax.bar(x + 2.0 * bar_width, OTH, bar_width, label='others', color=colors[4])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U9', 'U10', 'U11', 'U12', 'U13'])  # Update the labels to start from U9
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Num of News Articles', fontsize=14)

# Add a legend and title
ax.legend()

# Saving as eps plot image


# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
REP = [0, 4, 1, 2, 4]
DEM = [6, 6, 6, 4, 1]
UNB = [1, 2, 3, 0, 0]
MIC = [4, 8, 2, 10, 12]
OTH = [9, 0, 8, 4, 3]
x = np.arange(len(REP)) + 8  # Shift the x-axis values to start from U9
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 5)][::-1]  # Generate 5 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - 2.0 * bar_width, REP, bar_width, label='rep', color=colors[0])
ax.bar(x - 1.0 * bar_width, DEM, bar_width, label='dem', color=colors[1])
ax.bar(x, UNB, bar_width, label='unbiased', color=colors[2])
ax.bar(x + 1.0 * bar_width, MIC, bar_width, label='micro', color=colors[3])
ax.bar(x + 2.0 * bar_width, OTH, bar_width, label='others', color=colors[4])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['U9', 'U10', 'U11', 'U12', 'U13'], fontsize=16)  # Update the labels to start from U9
ax.set_xlabel('Users', fontsize=20)
ax.set_ylabel('Num of News Articles', fontsize=20)
ax.tick_params(axis='y', labelsize=16)

# Add a legend and title
ax.legend(fontsize=12)

# Saving as eps plot image
plt.savefig('fig_5_b_new2.eps', format='eps')

# Show the plot
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
