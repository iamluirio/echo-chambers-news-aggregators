# %% [markdown]
# # Positional Homophily in News Recommendation

# %% [markdown]
# As Google News ranks the news articles based on relevance to the user, we explore the positional homophily in news recommendation for an user, i.e., we study the first position of any news article that belong to the user’s macro news topic.

# %% [markdown]
# An user has high positional homophily in news recommendation if the news articles which match her macro news topic is ranked early in her news feed. For our experiment, we repeat this for all the users of both USAand India for 5 days, respectively.

# %% [markdown]
# ### India

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set data for the plot
firstDay = [1, 1, 2, 17, 1, 4]
secondDay = [2, 1, 2, 3, 2, 2]
thirdDay = [1, 1, 1, 1, 1, 1]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 3)][::-1]  # Generate 3 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - bar_width, firstDay, bar_width, label='12/04', color=colors[0])
ax.bar(x, secondDay, bar_width, label='13/04', color=colors[1])
ax.bar(x + bar_width, thirdDay, bar_width, label='14/04', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I1', 'I2', 'I3', 'I4', 'I5', 'I6'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Position', fontsize=14)

# Set the legend position
ax.legend(loc='upper right')

# Set only natural numbers in the Y-axis
ax.set_ylim([0, 18])
ax.yaxis.set_ticks(np.arange(0, 19, 1))

# Saving as eps plot image
#plt.savefig('fig_8_a.eps', format='eps')

# Show the plot
plt.show()

# %%
# Set data for the plot
firstDay = [1, 2, 1, 2]
secondDay = [2, 3, 1, 2]
thirdDay = [2, 1, 1, 2]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 3)][::-1]  # Generate 3 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - bar_width, firstDay, bar_width, label='12/04', color=colors[0])
ax.bar(x, secondDay, bar_width, label='13/04', color=colors[1])
ax.bar(x + bar_width, thirdDay, bar_width, label='14/04', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I7', 'I8', 'I9', 'I10'], fontsize=16)
ax.set_xlabel('Users', fontsize=20)
ax.set_ylabel('Position', fontsize=20)

ax.tick_params(axis='y', labelsize=16)

# Set the legend position
ax.legend(loc='upper right', fontsize=14)

# Set only natural numbers in the Y-axis
plt.yticks(np.arange(0, 5, 1))

# Saving as eps plot image
#plt.savefig('fig_8_a_new2.eps', format='eps')

# Show the plot
plt.show()

# %%
# Set data for the plot
firstDay = [1, 2, 0, 19, 3, 3]
secondDay = [2, 1, 2, 1, 3, 2]
thirdDay = [4, 2, 1, 1, 2, 2]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
ax.bar(x - bar_width, firstDay, bar_width, label='11/04', color='blue')
ax.bar(x, secondDay, bar_width, label='12/04', color='purple')
ax.bar(x + bar_width, thirdDay, bar_width, label='13/04', color='pink')

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I11', 'I12', 'I13', 'I14', 'I15', 'I16'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Position', fontsize=14)

# Set the legend position
ax.legend(loc='upper right')

# Set only natural numbers in the Y-axis
ax.set_ylim([0, 20])
ax.yaxis.set_ticks(np.arange(0, 21, 1))

# Saving as eps plot image
#plt.savefig('I11-I16.eps', format='eps')

# Show the plot
plt.show()

# %%
# Set data for the plot
firstDay = [1, 1, 1, 3]
secondDay = [1, 3, 1, 1]
thirdDay = [1, 2, 1, 1]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
colormap = plt.get_cmap('Blues')  # Choose the colormap
colors = [colormap(i) for i in np.linspace(0.2, 1, 3)][::-1]  # Generate 3 colors from the colormap starting at 0.2 and reverse the order

ax.bar(x - bar_width, firstDay, bar_width, label='11/04', color=colors[0])
ax.bar(x, secondDay, bar_width, label='12/04', color=colors[1])
ax.bar(x + bar_width, thirdDay, bar_width, label='13/04', color=colors[2])

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I17', 'I18', 'I19', 'I20'], fontsize=16)
ax.set_xlabel('Users', fontsize=20)
ax.set_ylabel('Position', fontsize=20)

ax.tick_params(axis='y', labelsize=16)

# Set the legend position
ax.legend(loc='upper right', fontsize=12)

# Set only natural numbers in the Y-axis
plt.yticks(np.arange(0, 5, 1))

# Saving as eps plot image
#plt.savefig('fig_8_b_new2.eps', format='eps')

# Show the plot
plt.show()
