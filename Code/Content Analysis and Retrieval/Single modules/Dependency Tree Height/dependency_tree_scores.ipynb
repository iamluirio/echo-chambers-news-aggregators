# %% [markdown]
# ## Average Length Scores Analysis

# %%
import matplotlib.pyplot as plt

# %%
avg_U1_02 = [5.31481481481482, 7.36363636363636, 4.16901408450704, 4.91346153846154, 5.53125, 8.1875, 5.97058823529412, 5.21875, 6.38461538461539, 5.65573770491803]
avg_U2_02 = [7.15555555555556, 5.58928571428571, 7.91304347826087, 5.37037037037037, 5.45762711864407, 5.33333333333333, 6.56666666666667, 5.78048780487805, 5.78048780487805, 0]
avg_U3_02 = [7.59090909090909, 6.26923076923077, 5.36363636363636, 7.15555555555556, 5.58928571428571, 7.91304347826087, 5.05263157894737, 4.97826086956522, 7.77966101694915, 4.1044776119403]
avg_U4_02 = [5.75, 6.4375, 4.44444444444444, 5.67567567567568, 7.15555555555556, 5.58928571428571, 7.91304347826087, 5.33333333333333, 6.1025641025641, 6.65909090909091]

avg_U1_03 = [6.53846153846154, 5.46875, 4.29032258064516, 5.81818181818182, 5.66666666666667, 6.77215189873418, 6, 6.31764705882353, 5.93333333333333, 5.54545454545455]
avg_U2_03 = [6.0625, 6.38333333333333, 5.55813953488372, 5.27777777777778, 5.46296296296296, 5.63793103448276, 4.76470588235294, 4.52380952380952, 5.05263157894737, 5.4]
avg_U3_03 = [7.97058823529412, 5.33333333333333, 4.85, 5.96078431372549, 4.875, 5.52631578947368, 6.35185185185185, 4.75, 5.7, 5.07352941176471]
avg_U4_03 = [7.22222222222222, 5.79166666666667, 5.52631578947368, 5.8125, 4.64285714285714, 2.6875, 6.31764705882353, 5.93333333333333, 5.54545454545455, 0]

avg_U1_04 = [6.2015503875969, 6.33333333333333, 6.22222222222222, 5.14285714285714, 6.08695652173913, 4.29166666666667, 7.73333333333333, 5.84507042253521, 4.52083333333333, 0]
avg_U2_04 = [7.23529411764706, 5.89473684210526, 6.21621621621622, 5.45833333333333, 6.81818181818182, 5.85714285714286, 5.05, 5.36666666666667, 5.20833333333333, 0]
avg_U3_04 = [5.22058823529412, 5, 6.92307692307692, 6.90909090909091, 7.81818181818182, 5.5, 5.57894736842105, 5.20588235294118, 5.5, 7.91428571428571]
avg_U4_04 = [7, 6.43396226415094, 6, 5.96296296296296, 4.75, 6.86666666666667, 6.68421052631579, 6.74074074074074, 6.19444444444444, 0]

# Dati per i boxplot
data_02 = [avg_U1_02, avg_U2_02, avg_U3_02, avg_U4_02]
data_03 = [avg_U1_03, avg_U2_03, avg_U3_03, avg_U4_03]
data_04 = [avg_U1_04, avg_U2_04, avg_U3_04, avg_U4_04]

# Etichette per gli assi x
labels = ['U1', 'U2', 'U3', 'U4']

# %%
# Creazione dei tre boxplot
plt.figure(figsize=(18, 6))

plt.suptitle('Top 10 news articles', fontsize=16)  # Titolo dell'immagine

plt.subplot(131)  # 1 riga, 3 colonne, primo plot
plt.boxplot(data_02, labels=labels)
plt.title('02/05/2023')
plt.xlabel('Users')
plt.ylabel('Scores')

plt.subplot(132)  # 1 riga, 3 colonne, secondo plot
plt.boxplot(data_03, labels=labels)
plt.title('03/05/2023')
plt.xlabel('Users')
plt.ylabel('Scores')

plt.subplot(133)  # 1 riga, 3 colonne, terzo plot
plt.boxplot(data_04, labels=labels)
plt.title('04/05/2023')
plt.xlabel('Users')
plt.ylabel('Scores')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Single images

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data_02, labels=labels)
plt.xlabel('Users')
plt.ylabel('Average Dependency Tree Length')
plt.tight_layout()
plt.savefig('avg_tree_02052023.eps', format='eps')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data_03, labels=labels)
plt.xlabel('Users')
plt.ylabel('Average Dependency Tree Length')
plt.tight_layout()
plt.savefig('avg_tree_03052023.eps', format='eps')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data_04, labels=labels)
plt.xlabel('Users')
plt.ylabel('Average Dependency Tree Length')
plt.tight_layout()
plt.savefig('avg_tree_04052023.eps', format='eps')
plt.show()

# %%
data_02 = [avg_U1_02[:4], avg_U2_02[:4], avg_U3_02[:4], avg_U4_02[:4]]
data_03 = [avg_U1_03[:4], avg_U2_03[:4], avg_U3_03[:4], avg_U4_03[:4]]
data_04 = [avg_U1_04[:4], avg_U2_04[:4], avg_U3_04[:4], avg_U4_04[:4]]

# Etichette per gli assi x
labels = ['User 1', 'User 2', 'User 3', 'User 4']

# Creazione dei tre boxplot
plt.figure(figsize=(18, 6))

plt.suptitle('Top 4 news articles', fontsize=16)  # Titolo dell'immagine

plt.subplot(131)  # 1 riga, 3 colonne, primo plot
plt.boxplot(data_02, labels=labels)
plt.title('02/05/2023')
plt.xlabel('Users')
plt.ylabel('Scores')

plt.subplot(132)  # 1 riga, 3 colonne, secondo plot
plt.boxplot(data_03, labels=labels)
plt.title('03/05/2023')
plt.xlabel('Users')
plt.ylabel('Scores')

plt.subplot(133)  # 1 riga, 3 colonne, terzo plot
plt.boxplot(data_04, labels=labels)
plt.title('04/05/2023')
plt.xlabel('Users')
plt.ylabel('Scores')

plt.tight_layout()
plt.show()
