# %% [markdown]
# I1 - I10 (Ananya B.)
#
# I1 - I6 political
# I7 - I10 macro and micro
#
# I11 - I20 (Ananya P.)
#
# I11 - I16 political
# I17 - I20 macro and micro
#
# note:
#
# - for user 4 Ananya B. (17) and Ananya P. (19), ask for the meaning.
#
# - Also, for Ananya B., I took the last values outside of the columns.
#
# - For U2 of Ananya P., 13 April, is written 2(2/3)?

# %% [markdown]
# # (Ananya B.) I1 - I6

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
firstDay = [1, 1, 2, 17, 1, 4]
secondDay = [2, 1, 2, 3, 2, 2]
thirdDay = [1, 1, 1, 1, 1, 1]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
ax.bar(x - bar_width, firstDay, bar_width, label='12/04', color='blue')
ax.bar(x, secondDay, bar_width, label='13/04', color='purple')
ax.bar(x + bar_width, thirdDay, bar_width, label='14/04', color='pink')

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I1', 'I2', 'I3', 'I4', 'I5', 'I6'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Position', fontsize=14)

# Set the legend position
ax.legend(loc='upper right')

# Set only natural numbers in the Y-axis
ax.set_ylim([0, 18])
ax.yaxis.set_ticks(np.arange(0, 19, 1))

# Saving as eps plot image
plt.savefig('I1-I6.eps', format='eps')

# Show the plot
plt.show()

# %% [markdown]
# # (Ananya B.) I7 - I10

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
firstDay = [1, 2, 1, 2]
secondDay = [2, 3, 1, 2]
thirdDay = [2, 1, 1, 2]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
ax.bar(x - bar_width, firstDay, bar_width, label='12/04', color='blue')
ax.bar(x, secondDay, bar_width, label='13/04', color='purple')
ax.bar(x + bar_width, thirdDay, bar_width, label='14/04', color='pink')

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I7', 'I8', 'I9', 'I10'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Position', fontsize=14)

# Set the legend position
ax.legend(loc='upper right')

# Set only natural numbers in the Y-axis
plt.yticks(np.arange(0, 5, 1))

# Saving as eps plot image
plt.savefig('I7-I10.eps', format='eps')

# Show the plot
plt.show()

# %% [markdown]
# # (Ananya P.) I11 - I16

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
firstDay = [1, 2, 0, 19, 3, 3]
secondDay = [2, 1, 2, 1, 3, 2]
thirdDay = [4, 2, 1, 1, 2, 2]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
ax.bar(x - bar_width, firstDay, bar_width, label='11/04', color='blue')
ax.bar(x, secondDay, bar_width, label='12/04', color='purple')
ax.bar(x + bar_width, thirdDay, bar_width, label='13/04', color='pink')

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I11', 'I12', 'I13', 'I14', 'I15', 'I16'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Position', fontsize=14)

# Set the legend position
ax.legend(loc='upper right')

# Set only natural numbers in the Y-axis
ax.set_ylim([0, 20])
ax.yaxis.set_ticks(np.arange(0, 21, 1))

# Saving as eps plot image
plt.savefig('I11-I16.eps', format='eps')

# Show the plot
plt.show()

# %% [markdown]
# # (Ananya P.) I17 - I20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set data for the plot
firstDay = [1, 1, 1, 3]
secondDay = [1, 3, 1, 1]
thirdDay = [1, 2, 1, 1]
x = np.arange(len(firstDay))  # x-axis values

# Set bar width
bar_width = 0.15

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))  # set the figure size to 12x8
ax.bar(x - bar_width, firstDay, bar_width, label='11/04', color='blue')
ax.bar(x, secondDay, bar_width, label='12/04', color='purple')
ax.bar(x + bar_width, thirdDay, bar_width, label='13/04', color='pink')

# Set the x-axis labels and ticks
ax.set_xticks(x)
ax.set_xticklabels(['I17', 'I18', 'I19', 'I20'])
ax.set_xlabel('Users', fontsize=14)
ax.set_ylabel('Position', fontsize=14)

# Set the legend position
ax.legend(loc='upper right')

# Set only natural numbers in the Y-axis
plt.yticks(np.arange(0, 5, 1))

# Saving as eps plot image
plt.savefig('I17-I20.eps', format='eps')

# Show the plot
plt.show()
